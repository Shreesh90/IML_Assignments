# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('HousingPrice.csv')

# %%
data
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0     5850         3        1        2      yes
# 1             2   38500.0     4000         2        1        1      yes
# 2             3   49500.0     3060         3        1        1      yes
# 3             4   60500.0     6650         3        1        2      yes
# 4             5   61000.0     6360         2        1        1      yes
# ..          ...       ...      ...       ...      ...      ...      ...
# 541         542   91500.0     4800         3        2        4      yes
# 542         543   94000.0     6000         3        2        4      yes
# 543         544  103000.0     6000         3        2        4      yes
# 544         545  105000.0     6000         3        2        2      yes
# 545         546  105000.0     6000         3        1        2      yes
#
#     recroom fullbase gashw airco  garagepl prefarea
# ...

# %%
colA = np.array(data.price)

# %%
colA = colA[:382]
colA
# Out:
# array([ 42000.,  38500.,  49500.,  60500.,  61000.,  66000.,  66000.,
#         69000.,  83800.,  88500.,  90000.,  30500.,  27000.,  36000.,
#         37000.,  37900.,  40500.,  40750.,  45000.,  45000.,  48500.,
#         65900.,  37900.,  38000.,  42000.,  42300.,  43500.,  44000.,
#         44500.,  44900.,  45000.,  48000.,  49000.,  51500.,  61000.,
#         61000.,  61700.,  67000.,  82000.,  54500.,  66500.,  70000.,
#         82000.,  92000.,  38000.,  44000.,  41000.,  43000.,  48000.,
#         54800.,  55000.,  57000.,  68000.,  95000.,  38000.,  25000.,
#         25245.,  56000.,  35500.,  30000.,  48000.,  48000.,  52000.,
#         54000.,  56000.,  60000.,  60000.,  67000.,  47000.,  70000.,
#         45000.,  51000.,  32500.,  34000.,  35000.,  36000.,  45000.,
#         47000.,  55000.,  63900.,  50000.,  35000.,  50000.,  43000.,
#         55500.,  57000.,  60000.,  78000.,  35000.,  44000.,  47000.,
# ...

# %%
colB = np.array(data.lotsize)[:382]

colC = np.array(data.bedrooms)[:382]

colD = np.array(data.bathrms)[:382]

len(colA)

mcolA = np.mat(colA)

mcolB = np.mat(colB)

mcolC = np.mat(colC)

mcolD = np.mat(colD)

xArray = []
yArray = []

m = len(colA) 

for i in range(0, m):
    xArray.append([1.0,float(colB[i]),float(colC[i]),float(colD[i])])
    yArray.append(float(colA[i]))
xmat = np.mat(xArray)
ymat = np.mat(yArray).T

# %%
n = xmat.shape[1]
print(n)
theta=[]
for i in range(0,n):
    theta.append(1)
# Out:
# 4

# %%
theta
# Out:
# [1, 1, 1, 1]

# %%
def gradientDescent(x, y, theta, alpha, m, numIterations):
    m = x.shape[0]
    for j in range(0,numIterations):
        copy = theta.copy
        for i in range(0,m):
            rem.append( (theta*xmat[i] - y[i])*xmat[j][i])
        for i in range(0,m):
            copy[i] = copy[i] - (alpha/m)*rem[i]
        theta = copy
    return theta

# %%
xmat.shape[0]
print(len(theta))
# Out:
# 4

# %%
theta = np.mat(theta).T

# %%
xmat[1]
# Out:
# matrix([[1.e+00, 4.e+03, 2.e+00, 1.e+00]])

# %%
ymat
# Out:
# matrix([[ 42000.],
#         [ 38500.],
#         [ 49500.],
#         [ 60500.],
#         [ 61000.],
#         [ 66000.],
#         [ 66000.],
#         [ 69000.],
#         [ 83800.],
#         [ 88500.],
#         [ 90000.],
#         [ 30500.],
#         [ 27000.],
#         [ 36000.],
#         [ 37000.],
#         [ 37900.],
#         [ 40500.],
#         [ 40750.],
#         [ 45000.],
#         [ 45000.],
#         [ 48500.],
#         [ 65900.],
#         [ 37900.],
#         [ 38000.],
#         [ 42000.],
#         [ 42300.],
#         [ 43500.],
#         [ 44000.],
#         [ 44500.],
#         [ 44900.],
#         [ 45000.],
#         [ 48000.],
#         [ 49000.],
#         [ 51500.],
#         [ 61000.],
#         [ 61000.],
#         [ 61700.],
#         [ 67000.],
#         [ 82000.],
#         [ 54500.],
#         [ 66500.],
#         [ 70000.],
#         [ 82000.],
#         [ 92000.],
#         [ 38000.],
#         [ 44000.],
#         [ 41000.],
# ...

# %%
xmat
# Out:
# matrix([[1.00e+00, 5.85e+03, 3.00e+00, 1.00e+00],
#         [1.00e+00, 4.00e+03, 2.00e+00, 1.00e+00],
#         [1.00e+00, 3.06e+03, 3.00e+00, 1.00e+00],
#         ...,
#         [1.00e+00, 4.00e+03, 3.00e+00, 2.00e+00],
#         [1.00e+00, 9.00e+03, 4.00e+00, 2.00e+00],
#         [1.00e+00, 6.55e+03, 3.00e+00, 1.00e+00]])

# %%
numIterations= 1000
alpha = 0.005
# theta = np.ones(n)

theta = gradientDescent(xmat, ymat, theta, alpha, m, numIterations)
print(theta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5q/gxhwzvxx0gq59nqc7kkcryz00000gn/T/ipykernel_20112/3022408125.py in <module>
#       3 # theta = np.ones(n)
#       4
# ----> 5 theta = gradientDescent(xmat, ymat, theta, alpha, m, numIterations)
#       6 print(theta)
#
# /var/folders/5q/gxhwzvxx0gq59nqc7kkcryz00000gn/T/ipykernel_20112/778401694.py in gradientDescent(x, y, theta, alpha, m, numIterations)
#       4         copy = theta.copy
#       5         for i in range(0,m):
# ----> 6             rem.append( (theta*xmat[i] - y[i])*xmat[j][i])
#       7         for i in range(0,m):
#       8             copy[i] = copy[i] - (alpha/m)*rem[i]
#
# NameError: name 'rem' is not defined

# %%
# def gradient_descent(X,y,theta,learning_rate=0.01,iterations=100):
#     '''
#     X    = Matrix of X with added bias units
#     y    = Vector of Y
#     theta=Vector of thetas np.random.randn(j,1)
#     learning_rate 
#     iterations = no of iterations
    
#     Returns the final theta vector and array of cost history over no of iterations
#     '''
#     m = len(y)
#     cost_history = np.zeros(iterations)
#     theta_history = np.zeros((iterations,2))
#     for it in range(iterations):
        
#         prediction = np.dot(X,theta)
        
#         theta = theta -(1/m)*learning_rate*( X.T.dot((prediction - y)))
#         theta_history[it,:] =theta.T
#         cost_history[it]  = cal_cost(theta,X,y)
        
#     return theta, cost_history, theta_history

# %%
# def  cal_cost(theta,X,y):
#     '''
    
#     Calculates the cost for given X and Y. The following shows and example of a single dimensional X
#     theta = Vector of thetas 
#     X     = Row of X's np.zeros((2,j))
#     y     = Actual y's np.zeros((2,1))
    
#     where:
#         j is the no of features
#     '''
    
#     m = len(y)
    
#     predictions = X.dot(theta)
#     cost = (1/2*m) * np.sum(np.square(predictions-y))
#     return cost

# %%
# lr = 0.00001
# n_iter=1000000
# theta,cost_history,theta_history = gradient_descent(xmat,ymat,theta,lr,n_iter)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-614cfb0eaf02> in <module>
#       1 lr = 0.00001
#       2 n_iter=1000000
# ----> 3 theta,cost_history,theta_history = gradient_descent(xmat,ymat,theta,lr,n_iter)
#
# <ipython-input-30-ae4df57acf4e> in gradient_descent(X, y, theta, learning_rate, iterations)
#      17
#      18         theta = theta -(1/m)*learning_rate*( X.T.dot((prediction - y)))
# ---> 19         theta_history[it,:] =theta.T
#      20         cost_history[it]  = cal_cost(theta,X,y)
#      21
#
# ValueError: could not broadcast input array from shape (4,) into shape (2,)
